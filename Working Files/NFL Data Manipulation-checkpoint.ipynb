# %%
import pandas as pd

# %%
spread_data = "NFL Datasets/spreadspoke_scores.csv"

spread_df = pd.read_csv(spread_data)

spread_df.head()
# Out:
#   schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0      9/2/1966             1966             1             False
# 1      9/3/1966             1966             1             False
# 2      9/4/1966             1966             1             False
# 3      9/9/1966             1966             2             False
# 4     9/10/1966             1966             1             False
#
#             team_home  score_home  score_away        team_away  \
# 0      Miami Dolphins          14          23  Oakland Raiders
# 1      Houston Oilers          45           7   Denver Broncos
# 2  San Diego Chargers          27           7    Buffalo Bills
# 3      Miami Dolphins          14          19    New York Jets
# 4   Green Bay Packers          24           3  Baltimore Colts
#
#   team_favorite_id  spread_favorite over_under_line         stadium  \
# 0              NaN              NaN             NaN     Orange Bowl
# ...

# %%
clean1_df = spread_df[spread_df['schedule_season']>2016]

clean1_df.head(50)
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 11877      9/7/2017             2017             1             False
# 11878     9/10/2017             2017             1             False
# 11879     9/10/2017             2017             1             False
# 11880     9/10/2017             2017             1             False
# 11881     9/10/2017             2017             1             False
# 11882     9/10/2017             2017             1             False
# 11883     9/10/2017             2017             1             False
# 11884     9/10/2017             2017             1             False
# 11885     9/10/2017             2017             1             False
# 11886     9/10/2017             2017             1             False
# 11887     9/10/2017             2017             1             False
# 11888     9/10/2017             2017             1             False
# 11889     9/10/2017             2017             1             False
# ...

# %%
data_columns = spread_df.dtypes[spread_df.dtypes == "object"].index.tolist()
data_columns
# Out:
# ['schedule_date',
#  'schedule_week',
#  'team_home',
#  'team_away',
#  'team_favorite_id',
#  'over_under_line',
#  'stadium',
#  'weather_humidity',
#  'weather_detail']

# %%
clean1_df = clean1_df.drop(["schedule_season", "stadium", "weather_humidity"],1)
clean1_df.head(10)
# Out:
#       schedule_date schedule_week  schedule_playoff             team_home  \
# 11877      9/7/2017             1             False  New England Patriots
# 11878     9/10/2017             1             False         Buffalo Bills
# 11879     9/10/2017             1             False         Chicago Bears
# 11880     9/10/2017             1             False    Cincinnati Bengals
# 11881     9/10/2017             1             False      Cleveland Browns
# 11882     9/10/2017             1             False        Dallas Cowboys
# 11883     9/10/2017             1             False         Detroit Lions
# 11884     9/10/2017             1             False     Green Bay Packers
# 11885     9/10/2017             1             False        Houston Texans
# 11886     9/10/2017             1             False      Los Angeles Rams
#
#        score_home  score_away             team_away team_favorite_id  \
# 11877          27          42    Kansas City Chiefs               NE
# ...

# %%
clean1_df = clean1_df[:-3]
clean1_df.head(10)
# Out:
#       schedule_date schedule_week  schedule_playoff             team_home  \
# 11877      9/7/2017             1             False  New England Patriots
# 11878     9/10/2017             1             False         Buffalo Bills
# 11879     9/10/2017             1             False         Chicago Bears
# 11880     9/10/2017             1             False    Cincinnati Bengals
# 11881     9/10/2017             1             False      Cleveland Browns
# 11882     9/10/2017             1             False        Dallas Cowboys
# 11883     9/10/2017             1             False         Detroit Lions
# 11884     9/10/2017             1             False     Green Bay Packers
# 11885     9/10/2017             1             False        Houston Texans
# 11886     9/10/2017             1             False      Los Angeles Rams
#
#        score_home  score_away             team_away team_favorite_id  \
# 11877          27          42    Kansas City Chiefs               NE
# ...
